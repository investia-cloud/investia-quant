# %%
import sys, os, importlib

_libs_py = os.path.abspath(os.path.join(os.getcwd(), '../libs_py'))
if _libs_py not in sys.path:
    sys.path.insert(0, _libs_py)

_libs = [
    'u_functions', 'k_tickers', 'r_functions', 'k_functions',
    's_functions', 't_functions', 'mc_functions', 'k_strategies',
    'k_portfolios', 'r_portfolios', 'l_portfolios'
]

for _lib in _libs:
    if _lib in sys.modules:
        importlib.reload(sys.modules[_lib])
    else:
        importlib.import_module(_lib)

from u_functions import *
from u_functions import (
    _TSLAB_INPUNTS_DIR, _TSLAB_OUTPUTS_DIR, _TSLAB_CACHE_DIR,
    _TSLAB_RUNTIME_T_WFO_RESULTS_DIR, _TSLAB_RUNTIME_R_WFO_RESULTS_DIR,
    _TSLAB_DEV_T_WFO_RESULTS_DIR, _TSLAB_DEV_R_WFO_RESULTS_DIR,
)
from k_tickers import *
from r_functions import *
from k_functions import *
from s_functions import *
from t_functions import *
from mc_functions import *
from k_strategies import *
from k_portfolios import *
from r_portfolios import *
from l_portfolios import *

print("\nRuntime dev completato.")
