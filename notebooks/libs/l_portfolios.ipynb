# %%
# --- Esempio di utilizzo ---

my_portfolio_test = {
    'AAPL': 0.5,
    'MSFT': 0.3,
    'TSLA': 0.2
}

my_portfolio_XX = {
    'IE00B5BMR087': 0.75,
    'IE00BYXYYM63': 0.25
}


robohuman_portfolio = {
    # 'TSLA': 0.30,
    '005380.KS': 0.35,
    '9984.T': 0.30,
    '6954.T': 0.20,
    'RBOT.MI': 0.15
}


ETF_PORT = {
    "SPY": 0.40,  # Core USA (S&P 500)
    "VT":  0.27,  # Global equity
    "IVV": 0.09,  # Quality proxy (USA large cap)
    "XLP": 0.06,  # LowVol proxy (Consumer Staples)
    "VTV": 0.03,  # Moat proxy (Value tilt)
    "AGG": 0.12,  # Bond aggregate
    "GLD": 0.03,  # Gold
}


# Proxy portfolio "Core-Satellite Patrimoniale 40" (NO-OVERLAP) per yfinance
# Obiettivo: sacrificare un po' di CAGR vs SP500, ma migliorare sensibilmente:
# - Max Drawdown
# - Volatilità
# - Sharpe/Calmar
#

PTF_NO_OVERLAP_IEF = {
    "SPY":  0.40,  # USA core (proxy VUAA)
    "VXUS": 0.22,  # Azionario ex-US (vera diversificazione geografica)
    "USMV": 0.12,  # Min Vol equity (difensivo equity "vero")
    "VTV":  0.06,  # Value tilt (proxy moat/quality pricing power)
    "IEF":  0.15,  # Treasury 7-10Y (cuscinetto in stress)
    "GLD":  0.05,  # Gold (hedge regime/inflazione/rischio sistemico)
}

# Variante "più prudente" (cuscinetto più stabile, meno duration risk)
PTF_NO_OVERLAP_SHY = {
    "SPY":  0.40,
    "VXUS": 0.22,
    "USMV": 0.12,
    "VTV":  0.06,
    "SHY":  0.15,  # Treasury 1-3Y (più stabile)
    "GLD":  0.05,
}



# Per test
greta_base_spy_portfolio = {
    'SPY'  : 0.60,  # 🌍 Azionario globale (S&P 500 UCITS - Vanguard)
    'GLD' : 0.20,  # 🟡 Oro fisico (GOLD.AS - Xetra Gold)
    'LYXC.DE' : 0.10,
    'MTD.PA'  : 0.10
}

# Portfolio Greta-Fiduciaria
# Etf disponibile su Borsa Italiana
greta_base_spy_portfolio_etf_ita = {
    "VUAA.MI": 0.60,      # 🇺🇸 Azionario USA large cap – S&P 500 (Accumulo) | Gestore: Vanguard
                          # Core growth del portafoglio, replica S&P 500 Total Return

    "SGLD.MI": 0.20,      # 🟡 Oro fisico – ETC fully backed (Accumulo) | Gestore: iShares (BlackRock)
                          # Hedge di regime: inflazione, crisi sistemiche, diversificazione

    "EM710.MI": 0.10,     # 🏛️ Titoli di Stato Area Euro 7–10 anni (Accumulo) | Gestore: Amundi
                          # Componente difensiva a duration media, stabilizzatore nei drawdown

    "EM1015.MI": 0.10,    # 🏛️ Titoli di Stato Area Euro 10–15 anni (Accumulo) | Gestore: Amundi
                          # Duration lunga, più sensibile ai tassi ma protettiva in shock recessivi
}


greta_alt_A = {
    "SPY": 0.38,      # USA core
    "VXUS": 0.17,     # Ex-US (diversificazione geografica reale)
    "QQQ": 0.10,      # Satellite growth (ridotto)
    "GLD": 0.12,      # Oro
    "LYXC.DE": 0.11,  # Gov EUR 5-7Y
    "MTD.PA": 0.12,   # Gov EUR 7-10Y
}

greta_alt_B = {
    "SPY": 0.40,     # USA core
    "USMV": 0.15,    # Min Vol USA (difensivo equity "vero")
    "QQQ": 0.10,     # Growth (ridotto)
    "GLD": 0.12,     # Oro
    "LYXC.DE": 0.11, # Gov EUR 5-7Y
    "MTD.PA": 0.12,  # Gov EUR 7-10Y
}

greta_alt_C = {
    "SPY": 0.40,
    "QQQ": 0.10,
    "GLD": 0.12,
    "LYXC.DE": 0.10,  # Gov EUR 5-7Y
    "MTD.PA": 0.08,   # Gov EUR 7-10Y (ridotto)
    "SHY": 0.20,      # Treasury USA 1-3Y (cuscinetto più stabile ai tassi)
}

# %%
print("Libreria l_portfolios importata.")
