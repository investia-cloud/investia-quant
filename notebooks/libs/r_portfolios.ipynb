# %%
# # Importo le definizioni statiche dei ticker
# %run k_tickers.ipynb

#
# Definizione dei portafogli rotazionali
#
portfolio_alpha_euro = {
    "Title" : "Alpha Euro",                   # Titolo del portafoglio
    "tickers" : stocks_euro,                  # Lista tickers
    "benchmark_portfolio" : None,             # Portfolio sintetico benchmart 
    "benchmark_title" : "^STOXX50E"           # Ticker di benckmart                  

}

portfolio_alpha_sect = {
    "Title" : "Alpha Sect (Megatrend)",                   # Titolo del portafoglio
    "tickers" : settoriali,                               # Lista tickers
    "benchmark_portfolio" : benchmark_settoriali,         # Portfolio sintetico benchmart 
    "benchmark_title" : 'Indice sintetico settoriali'     # Ticker di benckmart                  

}

portfolio_alpha_fact = {
    "Title" : "Alpha Fact",                   # Titolo del portafoglio
    "tickers" : fattoriali,                               # Lista tickers
    "benchmark_portfolio" : benchmark_fattoriali,         # Portfolio sintetico benchmart 
    "benchmark_title" : 'Indice sintetico fattoriali'     # Ticker di benckmart                  

}

portfolio_alpha_world = {
    "Title" : "Alpha World",                   # Titolo del portafoglio
    "tickers" : multiasset_global_ucits,       # Lista tickers
    "benchmark_portfolio" : None,              # Portfolio sintetico benchmart 
    "benchmark_title" : "SWDA.MI"              # Ticker di benckmart                  

}


portfolio_alpha_world_vanguard = {
    "Title" : "Alpha World Vanguard",          # Titolo del portafoglio
    "tickers" :  vanguard_etf,
    "benchmark_portfolio" : None,              # Portfolio sintetico benchmart 
    # "benchmark_title" : "SWDA.MI"              # Ticker di benckmart    
    "benchmark_title" : "V60A.DE"              # Ticker di benckmart                  
}

portfolio_alpha_quant = {
    "Title" : "Alpha Quant",                   # Titolo del portafoglio
    "tickers" : ai_dc_quantum_thematic,       # Lista tickers
    "benchmark_portfolio" : None,              # Portfolio sintetico benchmart 
    "benchmark_title" : "CSSPX.MI"              # Ticker di benckmart                  

}


year=2026

alpha_sp100_tickers_by_year = {
    2025: ['INTC', 'LLY', 'GOOGL', 'CAT', 'AVGO', 'AMD', 'IBM', 'GM', 'AMGN', 'NEE', 'JNJ', 'MDT', 'GILD', 'WMT', 'MS', 'CSCO', 'MMM', 'AXP', 'CVS', 'RTX', 'GS', 'ABBV', 'GE', 'C', 'KO'],
    2026: ['LLY', 'GM', 'AMD', 'GOOGL', 'CAT', 'AMGN', 'C', 'COF', 'CSCO', 'MS', 'INTC', 'WFC', 'AXP', 'JNJ', 'GILD', 'GS', 'AIG', 'RTX', 'WMT', 'IBM', 'BK', 'BAC', 'CVS', 'SCHW', 'AVGO']
}
portfolio_alpha_sp100 = {
    "Title" : "Alpha SP100",                             # Titolo del portafoglio
    # "tickers" : alpha_sp100_tickers_by_year[year],       # Lista tickers
    "tickers" : "sp100",                                 # indice
    "benchmark_portfolio" : None,                        # Portfolio sintetico benchmart 
    "benchmark_title" : "CSSPX.MI"                       # Ticker di benckmart                  

}

alpha_nasdaq100_tickers_by_year = {
    2025: ['WBD', 'MU', 'AMAT', 'LRCX', 'INTC', 'GOOGL', 'ASML', 'BIIB', 'AVGO', 'KLAC', 'AMD', 'APP', 'ROST', 'AMGN', 'MNST', 'CRWD', 'EA', 'IDXX', 'AZN', 'CEG', 'GILD', 'XEL', 'SHOP', 'AEP', 'CSCO'],
    2026: ['MU', 'WDC', 'WBD', 'AMD', 'LRCX', 'GOOGL', 'AMAT', 'INSM', 'AZN', 'ROST', 'STX', 'AMGN', 'KLAC', 'MNST', 'CSCO', 'ADI', 'GILD', 'FER', 'INTC', 'SHOP', 'ASML', 'CEG', 'IDXX', 'AVGO', 'AEP']
}
portfolio_alpha_nasdaq100 = {
    "Title" : "Alpha Nasdaq100",                           # Titolo del portafoglio
    # "tickers" : alpha_nasdaq100_tickers_by_year[year],   # Lista tickers
    "tickers" : "nasdaq100",                               # indice
    "benchmark_portfolio" : None,                          # Portfolio sintetico benchmart 
    "benchmark_title" : "CSNDX.MI"                         # Ticker di benckmart                  

}

portfolio_germany_plan = {
    "Title" : "Germany Plan",                    # Titolo del portafoglio
    "tickers" : germany_plan_beneficiaries,      # Lista tickers
    "benchmark_portfolio" : None,                # Portfolio sintetico benchmart 
    "benchmark_title" : "^GDAXI"                  # Ticker di benckmart: DAX Index                  
}

portfolio_italy_big_cap = {
    "Title" : "Italy Big Cap",                    # Titolo del portafoglio
    "tickers" : italy_bigcap_tickers,            # Lista tickers
    "benchmark_portfolio" : None,                # Portfolio sintetico benchmart 
    "benchmark_title" : "CSMIB.MI "              # Ticker di benckmart: DAX Index                  
}

# %%
print("Libreria r_portfolios importata.")
